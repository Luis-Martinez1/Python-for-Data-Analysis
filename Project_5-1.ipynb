# %% [markdown]
# # Chapter 5

# %%
import pandas as pd
import seaborn as sns

# %%
# 1. Download the CSV file at this link and read the data into a DataFrame:
# https://raw.githubusercontent.com/fivethirtyeight/data/master/thanksgiving-2015/thanksgiving-2015-poll-data.csv


# URL of the CSV file
url = "https://raw.githubusercontent.com/fivethirtyeight/data/master/thanksgiving-2015/thanksgiving-2015-poll-data.csv"

# Read the data into a DataFrame
thanksgiving_data = pd.read_csv(url)

thanksgiving_data.head()
# Out:
#    RespondentID Do you celebrate Thanksgiving?  \
# 0    4337954960                            Yes
# 1    4337951949                            Yes
# 2    4337935621                            Yes
# 3    4337933040                            Yes
# 4    4337931983                            Yes
#
#   What is typically the main dish at your Thanksgiving dinner?  \
# 0                                             Turkey
# 1                                             Turkey
# 2                                             Turkey
# 3                                             Turkey
# 4                                           Tofurkey
#
#   What is typically the main dish at your Thanksgiving dinner? - Other (please specify)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# ...

# %%
# 2. Download the Stata file at this link and read the data into a DataFrame:
url2= "http://www.stata-press.com/data/r8/cancer.dta"

# reading url link directly does not work

# download and read from current working directory

# Read the data into a DataFrame
cancer_data = pd.read_stata("url2")

cancer_data.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 9
#       2 url2= "http://www.stata-press.com/data/r8/cancer.dta"
#       4 # reading url link directly does not work
#       5
#       6 # download and read from current working directory
#       7
#       8 # Read the data into a DataFrame
# ----> 9 cancer_data = pd.read_stata("url2")
#      11 cancer_data.head()
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/pandas/io/stata.py:2090, in read_stata(filepath_or_buffer, convert_dates, convert_categoricals, index_col, convert_missing, preserve_dtypes, columns, order_categoricals, chunksize, iterator, compression, storage_options)
#    2087     return reader
#    2089 with reader:
# -> 2090     return reader.read()
#
# ...

# %%
# 3. Download the CSV file at this link and load the data into a DataFrame. You’ll need to
# create a Kaggle account if you do not already have one.
# https://www.kaggle.com/kaggle/sf-salaries


# URL of the CSV file
# path = "https://www.kaggle.com/kaggle/sf-salaries"

# Read the data into a DataFrame
salaries = pd.read_csv('Salaries.csv')

salaries.head()
# Out:
# /var/folders/6q/0n2ckzv123v3y8qcqf864bp80000gn/T/ipykernel_14810/2276565215.py:10: DtypeWarning: Columns (3,4,5,6,12) have mixed types. Specify dtype option on import or set low_memory=False.
#   salaries = pd.read_csv('Salaries.csv')
#    Id       EmployeeName                                        JobTitle  \
# 0   1     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2       GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5    PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#
#      BasePay OvertimePay   OtherPay Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.0  400184.25      NaN  567595.43         567595.43
# 1  155966.02   245131.88  137811.38      NaN  538909.28         538909.28
# 2  212739.13   106088.18    16452.6      NaN  335279.91         335279.91
# ...

# %%
salaries.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148654 entries, 0 to 148653
# Data columns (total 13 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Id                148654 non-null  int64
#  1   EmployeeName      148654 non-null  object
#  2   JobTitle          148654 non-null  object
#  3   BasePay           148049 non-null  object
#  4   OvertimePay       148654 non-null  object
#  5   OtherPay          148654 non-null  object
#  6   Benefits          112495 non-null  object
#  7   TotalPay          148654 non-null  float64
#  8   TotalPayBenefits  148654 non-null  float64
#  9   Year              148654 non-null  int64
#  10  Notes             0 non-null       float64
#  11  Agency            148654 non-null  object
#  12  Status            38119 non-null   object
# dtypes: float64(3), int64(2), object(8)
# memory usage: 14.7+ MB

# %%
from pydataset import data

data('tips', show_doc=True)
